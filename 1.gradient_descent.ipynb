# %%
import numpy as np

# %%
weight = 0.5
input = 0.5
goal_prediction = 0.8

step_amount = 10

# %%
for iteration in range(1101):
    
    prediction = input * weight
    error = (prediction - goal_prediction) ** 2
    
    print('Error :' + str(np.round(error, 5)) + ' Prediction :' + str(np.round(prediction, 5)))
    
    up_prediction = input * (weight + step_amount)
    up_error = (goal_prediction - up_prediction) ** 2
    
    down_prediction = input * (weight - step_amount)
    down_error = (goal_prediction - down_prediction) ** 2
    
    
    if (down_error < up_error):
        weight = weight - step_amount
        
    if (down_error > up_error):
        weight = weight + step_amount
# Out:
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# Error :19.8025 Prediction :5.25
# Error :0.3025 Prediction :0.25
# ...

# %%
weight = 0.5
input = 0.5
goal_prediction = 0.8

# %%
for iteration in range(20):
    pred = input * weight
    error = (pred - goal_prediction) ** 2
    direction_and_amount = (pred - goal_prediction) * input
    weight = weight - direction_and_amount
    print('Error :' + str(np.round(error, 10)) + ' Prediction :' + str(np.round(pred, 10)))
# Out:
# Error :0.3025 Prediction :0.25
# Error :0.17015625 Prediction :0.3875
# Error :0.0957128906 Prediction :0.490625
# Error :0.053838501 Prediction :0.56796875
# Error :0.0302841568 Prediction :0.6259765625
# Error :0.0170348382 Prediction :0.6694824219
# Error :0.0095820965 Prediction :0.7021118164
# Error :0.0053899293 Prediction :0.7265838623
# Error :0.0030318352 Prediction :0.7449378967
# Error :0.0017054073 Prediction :0.7587034225
# Error :0.0009592916 Prediction :0.7690275669
# Error :0.0005396015 Prediction :0.7767706752
# Error :0.0003035259 Prediction :0.7825780064
# Error :0.0001707333 Prediction :0.7869335048
# Error :9.60375e-05 Prediction :0.7902001286
# Error :5.40211e-05 Prediction :0.7926500964
# Error :3.03869e-05 Prediction :0.7944875723
# Error :1.70926e-05 Prediction :0.7958656792
# Error :9.6146e-06 Prediction :0.7968992594
# Error :5.4082e-06 Prediction :0.7976744446

# %%
weight = 0.1
alpha = 0.01

def neural_network(input, weight):
    prediction = input * weight
    return prediction

# %%
number_of_toes = [8.5]
win_or_lose_binary = [1]

input = number_of_toes[0]
goal_pred = win_or_lose_binary[0]

pred = neural_network(input, weight)
print('pred :', np.round(pred, 4))

error = (pred - goal_pred) ** 2
print('error :', np.round(error, 4))

delta = pred - goal_pred
print('delta :', np.round(delta, 4))

weight_delta = input * delta
print('weight_delta :', np.round(weight_delta, 4))
# Out:
# pred : 0.85
# error : 0.0225
# delta : -0.15
# weight_delta : -1.275

# %%
weight -= weight_delta * alpha

# %%
weight
# Out:
# 0.11275

# %%
weight, goal_pred, input = (0, 0.8, 1.1)

for iteration in range(4):
    print('-----\nWeight:' + str(weight))
    pred = input * weight
    error = (pred - goal_pred) ** 2
    delta = pred - goal_pred
    weight_delta = delta * input
    weight = weight - weight_delta
    print('Error: ' + str(error) + ' Prediction: ' + str(pred))
    print('Delta: ' + str(delta) + ' Weight Delta: ' + str(weight_delta))
# Out:
# -----
# Weight:0
# Error: 0.6400000000000001 Prediction: 0.0
# Delta: -0.8 Weight Delta: -0.8800000000000001
# -----
# Weight:0.8800000000000001
# Error: 0.02822400000000005 Prediction: 0.9680000000000002
# Delta: 0.16800000000000015 Weight Delta: 0.1848000000000002
# -----
# Weight:0.6951999999999999
# Error: 0.0012446784000000064 Prediction: 0.76472
# Delta: -0.03528000000000009 Weight Delta: -0.0388080000000001
# -----
# Weight:0.734008
# Error: 5.4890317439999896e-05 Prediction: 0.8074088
# Delta: 0.007408799999999993 Weight Delta: 0.008149679999999992

# %%
weight, goal_pred, input, alpha = (0.5, 0.8, 2, 0.1)

# %%
for iter in range(50):
    pred = weight * input
    error = (pred - goal_pred) ** 2
    delta = pred - goal_pred
    weight_delta = input * delta 
    weight = weight - alpha * weight_delta
    print('Error: ' + str(error) + ' Prediction: ' + str(pred))
# Out:
# Error: 7.147597971337652e-20 Prediction: 0.80000000026735
# Error: 2.5731338449551755e-20 Prediction: 0.80000000016041
# Error: 9.263273293483511e-21 Prediction: 0.800000000096246
# Error: 3.3347835146679253e-21 Prediction: 0.8000000000577476
# Error: 1.2005189878729251e-21 Prediction: 0.8000000000346486
# Error: 4.321886820795587e-22 Prediction: 0.8000000000207892
# Error: 1.5558737161495083e-22 Prediction: 0.8000000000124735
# Error: 5.601211850319117e-23 Prediction: 0.8000000000074842
# Error: 2.0164761497389587e-23 Prediction: 0.8000000000044906
# Error: 7.259194488089414e-24 Prediction: 0.8000000000026943
# Error: 2.6133818064919067e-24 Prediction: 0.8000000000016166
# Error: 9.409036018365456e-25 Prediction: 0.80000000000097
# Error: 3.3869945111271105e-25 Prediction: 0.800000000000582
# Error: 1.2191629586036966e-25 Prediction: 0.8000000000003492
# Error: 4.388986650973308e-26 Prediction: 0.8000000000002095
# Error: 1.5794770259561404e-26 Prediction: 0.8000000000001257
# ...

# %%
def

# %%
weight, goal_pred, input, alpha = (0.5, 1, 0.9, 0.1)

# %%
for iter in range(50):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    delta = pred - goal_pred
    weight_delta = delta * input
    weight = weight - alpha * weight_delta
    print('Error: ' + str(error) + ' Prediction: ' + str(pred))
# Out:
# Error: 0.30250000000000005 Prediction: 0.45
# Error: 0.25547970249999996 Prediction: 0.49455
# Error: 0.21576819302310252 Prediction: 0.53549145
# Error: 0.1822294008677844 Prediction: 0.57311664255
# Error: 0.15390384502629686 Prediction: 0.6076941945034501
# Error: 0.1299811852592543 Prediction: 0.6394709647486706
# Error: 0.10977703980374104 Prediction: 0.6686738166040284
# Error: 0.09271340651368734 Prediction: 0.695511237459102
# Error: 0.0783021273186063 Prediction: 0.7201748272249148
# Error: 0.06613092295032945 Prediction: 0.7428406662196967
# Error: 0.05585159841785317 Prediction: 0.7636705722559013
# Error: 0.047170081811380535 Prediction: 0.7828132559031732
# Error: 0.03983801146470133 Prediction: 0.8004053821750162
# Error: 0.033645630800639585 Prediction: 0.81657254621884
# Error: 0.028415787594619 Prediction: 0.8314301699751139
# Error: 0.023998865986699 Prediction: 0.8450843262071297
# Error: 0.020268506256592496 Prediction: 0.8576324957843522
# ...

# %%
weight, goal_pred, input, alpha = (0.5, 1, 0.9, 0.1)

# %%
for iter in range(50):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    weight -= alpha * (input * weight - goal_pred) * input
    print('Error: ' + str(error) + ' Prediction: ' + str(pred))
# Out:
# Error: 0.30250000000000005 Prediction: 0.45
# Error: 0.25547970249999996 Prediction: 0.49455
# Error: 0.21576819302310252 Prediction: 0.53549145
# Error: 0.1822294008677844 Prediction: 0.57311664255
# Error: 0.15390384502629686 Prediction: 0.6076941945034501
# Error: 0.1299811852592543 Prediction: 0.6394709647486706
# Error: 0.10977703980374104 Prediction: 0.6686738166040284
# Error: 0.09271340651368734 Prediction: 0.695511237459102
# Error: 0.0783021273186063 Prediction: 0.7201748272249148
# Error: 0.06613092295032945 Prediction: 0.7428406662196967
# Error: 0.05585159841785317 Prediction: 0.7636705722559013
# Error: 0.047170081811380535 Prediction: 0.7828132559031732
# Error: 0.03983801146470133 Prediction: 0.8004053821750162
# Error: 0.033645630800639585 Prediction: 0.81657254621884
# Error: 0.028415787594619 Prediction: 0.8314301699751139
# Error: 0.023998865986699 Prediction: 0.8450843262071297
# Error: 0.020268506256592496 Prediction: 0.8576324957843522
# ...
