# %% [markdown]
# ## Библиотеки

# %%
import numpy as np
import sys
from keras.datasets import mnist

# %% [markdown]
# ## Данные

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# Возьмем 1000 наблюдений и вытянем картинки в вектор и отцентрируем и нормируем. 
images, labels = x_train[0:1000].reshape(1000, 28*28) / 255, y_train[0:1000]
# Закодируем категориальный признак.
one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels
test_images = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
    test_labels[i][l] = 1

# %%
# Зададим параметры.
alpha = 2
iterations = 300
hidden_size = 100
pixels_per_image = 784
num_labels = 10
batch_size = 128

input_rows = 28
input_cols = 28

kernel_rows = 3
kernel_cols = 3
num_kernels = 16

# %%
# Функции активации.
def tanh(x):
    return np.tanh(x)

def tang2deriv(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims=True)

# %%
hidden_size = ((input_rows - kernel_rows) *
               (input_cols - kernel_cols)) * num_kernels
kernels = 0.02 * np.random.random(((kernel_rows * kernel_cols, num_kernels))) - 0.01
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

# %%
def get_image_section(layer, row_from, row_to, col_from, col_to):
    sub_section = layer[ : , row_from : row_to, col_from : col_to]
    return sub_section.reshape(-1, 1, row_to-row_from, col_to-col_from)

# %%
for iter in range(iterations):
    correct_cnt = 0
    for i in range(int(len(images) / batch_size)):
        
        batch_start, batch_end = (i * batch_size), ((i+1) * batch_size)
        layer_0 = images[batch_start : batch_end]
        layer_0 = layer_0.reshape(layer_0.shape[0], 28, 28)
        
        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                    sect = get_image_section(layer_0,
                                            row_start,
                                            row_start+kernel_rows,
                                            col_start,
                                            col_start+kernel_cols)
                    sects.append(sect)

        expanded_input = np.concatenate(sects, axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0] * es[1], -1)
        
        kernel_ooutput = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_ooutput.reshape(es[0], -1))
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = softmax(layer_1.dot(weights_1_2))
        
        for k in range(batch_size):
            correct_cnt += int(np.argmax(layer_2[k : k+1]) == np.argmax(labels[batch_start+k : batch_start+k+1]))
            
        layer_2_delta = (layer_2 - labels[batch_start : batch_end]) / (batch_size * layer_2.shape[0])
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * tang2deriv(layer_1)
        layer_1_delta *= dropout_mask
        
        weights_1_2 -= alpha * layer_1.T.dot(layer_2_delta)
        l1d_reshape = layer_1_delta.reshape(kernel_ooutput.shape)
        k_update = flattened_input.T.dot(l1d_reshape)
        kernels -= alpha * k_update
        
    test_correct_cnt = 0
    for j in range(len(test_labels)):
        layer_0 = test_images[j : j+1]
        layer_0 = layer_0.reshape(layer_0.shape[0], 28, 28)
        
        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                    sect = get_image_section(layer_0,
                                            row_start,
                                            row_start+kernel_rows,
                                            col_start,
                                            col_start+kernel_cols)
                    sects.append(sect)
    
        expanded_input = np.concatenate(sects, axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0] * es[1], -1)
        
        kernel_ooutput = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_ooutput.reshape(es[0], -1))
        layer_2 = layer_1.dot(weights_1_2)
        
        test_correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[j : j+1]))

    if (iter % 1 == 0):  
        sys.stdout.write('\n' + 'I : ' + str(iter) + ' Train-Acc : ' + str(correct_cnt/float(len(images/batch_size))) + ' Test-Acc : ' + str(test_correct_cnt/float(len(test_images/batch_size))))
# Out:
# I : 0 Train-Acc : 0.15 Test-Acc : 0.2653
# I : 1 Train-Acc : 0.2 Test-Acc : 0.2789
# I : 2 Train-Acc : 0.205 Test-Acc : 0.3026
# I : 3 Train-Acc : 0.213 Test-Acc : 0.3462
# I : 4 Train-Acc : 0.216 Test-Acc : 0.3706
# I : 5 Train-Acc : 0.264 Test-Acc : 0.4034
# I : 6 Train-Acc : 0.282 Test-Acc : 0.4402
# I : 7 Train-Acc : 0.314 Test-Acc : 0.4866
# I : 8 Train-Acc : 0.339 Test-Acc : 0.5353
# I : 9 Train-Acc : 0.373 Test-Acc : 0.5845
# I : 10 Train-Acc : 0.407 Test-Acc : 0.6233
# I : 11 Train-Acc : 0.422 Test-Acc : 0.6539
# I : 12 Train-Acc : 0.455 Test-Acc : 0.681
# I : 13 Train-Acc : 0.49 Test-Acc : 0.7001
# I : 14 Train-Acc : 0.527 Test-Acc : 0.716
# I : 15 Train-Acc : 0.536 Test-Acc : 0.726
# I : 16 Train-Acc : 0.549 Test-Acc : 0.7377
# I : 17 Train-Acc : 0.567 Test-Acc : 0.7437
# I : 18 Train-Acc : 0.579 Test-Acc : 0.7543
# I : 19 Train-Acc : 0.58 Test-Acc : 0.7617
# I : 20 Train-Acc : 0.615 Test-Acc : 0.7681
# I : 21 Train-Acc : 0.624 Test-Acc : 0.7733
# I : 22 Train-Acc : 0.644 Test-Acc : 0.778
# I : 23 Train-Acc : 0.642 Test-Acc : 0.7799
# I : 24 Train-Acc : 0.66 Test-Acc : 0.7835
# I : 25 Train-Acc : 0.644 Test-Acc : 0.7877
# I : 26 Train-Acc : 0.65 Test-Acc : 0.791
# I : 27 Train-Acc : 0.666 Test-Acc : 0.7931
# I : 28 Train-Acc : 0.692 Test-Acc : 0.7963
# I : 29 Train-Acc : 0.687 Test-Acc : 0.7994
# I : 30 Train-Acc : 0.69 Test-Acc : 0.8006
# I : 31 Train-Acc : 0.699 Test-Acc : 0.8032
# I : 32 Train-Acc : 0.683 Test-Acc : 0.8059
# I : 33 Train-Acc : 0.69 Test-Acc : 0.8068
# I : 34 Train-Acc : 0.679 Test-Acc : 0.8105
# I : 35 Train-Acc : 0.685 Test-Acc : 0.811
# I : 36 Train-Acc : 0.699 Test-Acc : 0.8108
# I : 37 Train-Acc : 0.69 Test-Acc : 0.8142
# I : 38 Train-Acc : 0.714 Test-Acc : 0.8159
# I : 39 Train-Acc : 0.702 Test-Acc : 0.8172
# I : 40 Train-Acc : 0.705 Test-Acc : 0.8202
# I : 41 Train-Acc : 0.719 Test-Acc : 0.822
# I : 42 Train-Acc : 0.717 Test-Acc : 0.823
# I : 43 Train-Acc : 0.72 Test-Acc : 0.8229
# I : 44 Train-Acc : 0.724 Test-Acc : 0.8244
# I : 45 Train-Acc : 0.729 Test-Acc : 0.8258
# I : 46 Train-Acc : 0.719 Test-Acc : 0.8277
# I : 47 Train-Acc : 0.736 Test-Acc : 0.8277
# I : 48 Train-Acc : 0.724 Test-Acc : 0.8286
# I : 49 Train-Acc : 0.719 Test-Acc : 0.8297
# I : 50 Train-Acc : 0.736 Test-Acc : 0.8315
# I : 51 Train-Acc : 0.719 Test-Acc : 0.833
# I : 52 Train-Acc : 0.732 Test-Acc : 0.8331
# I : 53 Train-Acc : 0.736 Test-Acc : 0.8342
# I : 54 Train-Acc : 0.735 Test-Acc : 0.836
# I : 55 Train-Acc : 0.729 Test-Acc : 0.8369
# I : 56 Train-Acc : 0.743 Test-Acc : 0.8389
# I : 57 Train-Acc : 0.731 Test-Acc : 0.8389
# I : 58 Train-Acc : 0.753 Test-Acc : 0.8405
# I : 59 Train-Acc : 0.732 Test-Acc : 0.841
# I : 60 Train-Acc : 0.74 Test-Acc : 0.8429
# I : 61 Train-Acc : 0.73 Test-Acc : 0.8429
# I : 62 Train-Acc : 0.741 Test-Acc : 0.8423
# I : 63 Train-Acc : 0.75 Test-Acc : 0.8428
# I : 64 Train-Acc : 0.745 Test-Acc : 0.8436
# I : 65 Train-Acc : 0.743 Test-Acc : 0.844
# I : 66 Train-Acc : 0.752 Test-Acc : 0.8444
# I : 67 Train-Acc : 0.755 Test-Acc : 0.8451
# I : 68 Train-Acc : 0.749 Test-Acc : 0.8449
# I : 69 Train-Acc : 0.752 Test-Acc : 0.8463
# I : 70 Train-Acc : 0.753 Test-Acc : 0.8472
# I : 71 Train-Acc : 0.758 Test-Acc : 0.8475
# I : 72 Train-Acc : 0.75 Test-Acc : 0.8476
# I : 73 Train-Acc : 0.758 Test-Acc : 0.8474
# I : 74 Train-Acc : 0.759 Test-Acc : 0.8493
# I : 75 Train-Acc : 0.754 Test-Acc : 0.8492
# I : 76 Train-Acc : 0.751 Test-Acc : 0.8509
# I : 77 Train-Acc : 0.755 Test-Acc : 0.8503
# I : 78 Train-Acc : 0.758 Test-Acc : 0.8512
# I : 79 Train-Acc : 0.773 Test-Acc : 0.8525
# I : 80 Train-Acc : 0.754 Test-Acc : 0.8524
# I : 81 Train-Acc : 0.765 Test-Acc : 0.8528
# I : 82 Train-Acc : 0.764 Test-Acc : 0.8525
# I : 83 Train-Acc : 0.768 Test-Acc : 0.8544
# I : 84 Train-Acc : 0.756 Test-Acc : 0.8539
# I : 85 Train-Acc : 0.763 Test-Acc : 0.8541
# I : 86 Train-Acc : 0.772 Test-Acc : 0.8547
# I : 87 Train-Acc : 0.761 Test-Acc : 0.854
# I : 88 Train-Acc : 0.759 Test-Acc : 0.8548
# I : 89 Train-Acc : 0.764 Test-Acc : 0.8545
# I : 90 Train-Acc : 0.764 Test-Acc : 0.8552
# I : 91 Train-Acc : 0.768 Test-Acc : 0.8552
# I : 92 Train-Acc : 0.76 Test-Acc : 0.8552
# I : 93 Train-Acc : 0.769 Test-Acc : 0.855
# I : 94 Train-Acc : 0.777 Test-Acc : 0.8563
# I : 95 Train-Acc : 0.774 Test-Acc : 0.8558
# I : 96 Train-Acc : 0.766 Test-Acc : 0.8571
# I : 97 Train-Acc : 0.772 Test-Acc : 0.857
# I : 98 Train-Acc : 0.776 Test-Acc : 0.8571
# I : 99 Train-Acc : 0.764 Test-Acc : 0.8576
# I : 100 Train-Acc : 0.768 Test-Acc : 0.8576
# I : 101 Train-Acc : 0.767 Test-Acc : 0.8576
# I : 102 Train-Acc : 0.772 Test-Acc : 0.858
# I : 103 Train-Acc : 0.79 Test-Acc : 0.8589
# I : 104 Train-Acc : 0.778 Test-Acc : 0.8583
# I : 105 Train-Acc : 0.777 Test-Acc : 0.8596
# I : 106 Train-Acc : 0.766 Test-Acc : 0.8578
# I : 107 Train-Acc : 0.776 Test-Acc : 0.8604
# I : 108 Train-Acc : 0.773 Test-Acc : 0.8595
# I : 109 Train-Acc : 0.77 Test-Acc : 0.8585
# I : 110 Train-Acc : 0.775 Test-Acc : 0.8598
# I : 111 Train-Acc : 0.773 Test-Acc : 0.8609
# I : 112 Train-Acc : 0.779 Test-Acc : 0.8605
# I : 113 Train-Acc : 0.781 Test-Acc : 0.861
# I : 114 Train-Acc : 0.789 Test-Acc : 0.8618
# I : 115 Train-Acc : 0.783 Test-Acc : 0.8615
# I : 116 Train-Acc : 0.781 Test-Acc : 0.8608
# I : 117 Train-Acc : 0.779 Test-Acc : 0.8605
# I : 118 Train-Acc : 0.79 Test-Acc : 0.8619
# I : 119 Train-Acc : 0.778 Test-Acc : 0.8627
# I : 120 Train-Acc : 0.788 Test-Acc : 0.8627
# I : 121 Train-Acc : 0.792 Test-Acc : 0.8639
# I : 122 Train-Acc : 0.779 Test-Acc : 0.8639
# I : 123 Train-Acc : 0.779 Test-Acc : 0.8638
# I : 124 Train-Acc : 0.789 Test-Acc : 0.8646
# I : 125 Train-Acc : 0.782 Test-Acc : 0.8642
# I : 126 Train-Acc : 0.787 Test-Acc : 0.8636
# I : 127 Train-Acc : 0.793 Test-Acc : 0.864
# I : 128 Train-Acc : 0.78 Test-Acc : 0.864
# I : 129 Train-Acc : 0.79 Test-Acc : 0.8648
# I : 130 Train-Acc : 0.799 Test-Acc : 0.8657
# I : 131 Train-Acc : 0.791 Test-Acc : 0.8653
# I : 132 Train-Acc : 0.794 Test-Acc : 0.8659
# I : 133 Train-Acc : 0.793 Test-Acc : 0.8648
# I : 134 Train-Acc : 0.795 Test-Acc : 0.8665
# I : 135 Train-Acc : 0.78 Test-Acc : 0.8666
# I : 136 Train-Acc : 0.796 Test-Acc : 0.8663
# I : 137 Train-Acc : 0.779 Test-Acc : 0.8672
# I : 138 Train-Acc : 0.788 Test-Acc : 0.8653
# I : 139 Train-Acc : 0.804 Test-Acc : 0.8662
# I : 140 Train-Acc : 0.772 Test-Acc : 0.8672
# I : 141 Train-Acc : 0.784 Test-Acc : 0.866
# I : 142 Train-Acc : 0.795 Test-Acc : 0.866
# I : 143 Train-Acc : 0.784 Test-Acc : 0.8659
# I : 144 Train-Acc : 0.803 Test-Acc : 0.8664
# I : 145 Train-Acc : 0.796 Test-Acc : 0.8671
# I : 146 Train-Acc : 0.795 Test-Acc : 0.8682
# I : 147 Train-Acc : 0.776 Test-Acc : 0.8681
# I : 148 Train-Acc : 0.792 Test-Acc : 0.8686
# I : 149 Train-Acc : 0.795 Test-Acc : 0.8678
# I : 150 Train-Acc : 0.8 Test-Acc : 0.8677
# I : 151 Train-Acc : 0.799 Test-Acc : 0.8674
# I : 152 Train-Acc : 0.788 Test-Acc : 0.8676
# I : 153 Train-Acc : 0.792 Test-Acc : 0.8676
# I : 154 Train-Acc : 0.79 Test-Acc : 0.8682
# I : 155 Train-Acc : 0.794 Test-Acc : 0.8685
# I : 156 Train-Acc : 0.794 Test-Acc : 0.8679
# I : 157 Train-Acc : 0.802 Test-Acc : 0.8683
# I : 158 Train-Acc : 0.808 Test-Acc : 0.8682
# I : 159 Train-Acc : 0.79 Test-Acc : 0.8681
# I : 160 Train-Acc : 0.805 Test-Acc : 0.8686
# I : 161 Train-Acc : 0.795 Test-Acc : 0.8688
# I : 162 Train-Acc : 0.795 Test-Acc : 0.8689
# I : 163 Train-Acc : 0.802 Test-Acc : 0.8691
# I : 164 Train-Acc : 0.812 Test-Acc : 0.869
# I : 165 Train-Acc : 0.801 Test-Acc : 0.8682
# I : 166 Train-Acc : 0.799 Test-Acc : 0.8681
# I : 167 Train-Acc : 0.805 Test-Acc : 0.8694
# I : 168 Train-Acc : 0.792 Test-Acc : 0.8691
# I : 169 Train-Acc : 0.8 Test-Acc : 0.8694
# I : 170 Train-Acc : 0.801 Test-Acc : 0.8694
# I : 171 Train-Acc : 0.787 Test-Acc : 0.8697
# I : 172 Train-Acc : 0.798 Test-Acc : 0.8695
# I : 173 Train-Acc : 0.8 Test-Acc : 0.8691
# I : 174 Train-Acc : 0.808 Test-Acc : 0.869
# I : 175 Train-Acc : 0.808 Test-Acc : 0.8688
# I : 176 Train-Acc : 0.796 Test-Acc : 0.8691
# I : 177 Train-Acc : 0.796 Test-Acc : 0.8687
# I : 178 Train-Acc : 0.791 Test-Acc : 0.8684
# I : 179 Train-Acc : 0.81 Test-Acc : 0.8691
# I : 180 Train-Acc : 0.801 Test-Acc : 0.8695
# I : 181 Train-Acc : 0.805 Test-Acc : 0.8697
# I : 182 Train-Acc : 0.809 Test-Acc : 0.8695
# I : 183 Train-Acc : 0.807 Test-Acc : 0.8692
# I : 184 Train-Acc : 0.801 Test-Acc : 0.8692
# I : 185 Train-Acc : 0.808 Test-Acc : 0.8695
# I : 186 Train-Acc : 0.8 Test-Acc : 0.8704
# I : 187 Train-Acc : 0.807 Test-Acc : 0.8708
# I : 188 Train-Acc : 0.801 Test-Acc : 0.8709
# I : 189 Train-Acc : 0.812 Test-Acc : 0.8704
# I : 190 Train-Acc : 0.81 Test-Acc : 0.8704
# I : 191 Train-Acc : 0.811 Test-Acc : 0.8709
# I : 192 Train-Acc : 0.808 Test-Acc : 0.8716
# I : 193 Train-Acc : 0.804 Test-Acc : 0.8707
# I : 194 Train-Acc : 0.8 Test-Acc : 0.87
# I : 195 Train-Acc : 0.804 Test-Acc : 0.8704
# I : 196 Train-Acc : 0.807 Test-Acc : 0.8702
# I : 197 Train-Acc : 0.803 Test-Acc : 0.871
# I : 198 Train-Acc : 0.808 Test-Acc : 0.8708
# I : 199 Train-Acc : 0.812 Test-Acc : 0.8706
# I : 200 Train-Acc : 0.814 Test-Acc : 0.8705
# I : 201 Train-Acc : 0.818 Test-Acc : 0.8707
# I : 202 Train-Acc : 0.821 Test-Acc : 0.8718
# I : 203 Train-Acc : 0.814 Test-Acc : 0.8708
# I : 204 Train-Acc : 0.814 Test-Acc : 0.87
# I : 205 Train-Acc : 0.8 Test-Acc : 0.8716
# I : 206 Train-Acc : 0.806 Test-Acc : 0.8715
# I : 207 Train-Acc : 0.821 Test-Acc : 0.8718
# I : 208 Train-Acc : 0.814 Test-Acc : 0.8722
# I : 209 Train-Acc : 0.805 Test-Acc : 0.8707
# I : 210 Train-Acc : 0.809 Test-Acc : 0.8704
# I : 211 Train-Acc : 0.815 Test-Acc : 0.8708
# I : 212 Train-Acc : 0.815 Test-Acc : 0.8706
# I : 213 Train-Acc : 0.813 Test-Acc : 0.871
# I : 214 Train-Acc : 0.82 Test-Acc : 0.8713
# I : 215 Train-Acc : 0.802 Test-Acc : 0.8704
# I : 216 Train-Acc : 0.815 Test-Acc : 0.8712
# I : 217 Train-Acc : 0.816 Test-Acc : 0.8711
# I : 218 Train-Acc : 0.816 Test-Acc : 0.8709
# I : 219 Train-Acc : 0.811 Test-Acc : 0.871
# I : 220 Train-Acc : 0.817 Test-Acc : 0.8712
# I : 221 Train-Acc : 0.808 Test-Acc : 0.8711
# I : 222 Train-Acc : 0.815 Test-Acc : 0.8709
# I : 223 Train-Acc : 0.809 Test-Acc : 0.8708
# I : 224 Train-Acc : 0.817 Test-Acc : 0.87
# I : 225 Train-Acc : 0.807 Test-Acc : 0.8709
# I : 226 Train-Acc : 0.819 Test-Acc : 0.8708
# I : 227 Train-Acc : 0.81 Test-Acc : 0.8706
# I : 228 Train-Acc : 0.826 Test-Acc : 0.8709
# I : 229 Train-Acc : 0.808 Test-Acc : 0.8715
# I : 230 Train-Acc : 0.815 Test-Acc : 0.8714
# I : 231 Train-Acc : 0.807 Test-Acc : 0.8719
# I : 232 Train-Acc : 0.817 Test-Acc : 0.8704
# I : 233 Train-Acc : 0.808 Test-Acc : 0.8711
# I : 234 Train-Acc : 0.808 Test-Acc : 0.8707
# I : 235 Train-Acc : 0.834 Test-Acc : 0.8704
# I : 236 Train-Acc : 0.817 Test-Acc : 0.8703
# I : 237 Train-Acc : 0.809 Test-Acc : 0.8693
# I : 238 Train-Acc : 0.815 Test-Acc : 0.8704
# I : 239 Train-Acc : 0.807 Test-Acc : 0.8709
# I : 240 Train-Acc : 0.837 Test-Acc : 0.8709
# I : 241 Train-Acc : 0.811 Test-Acc : 0.8703
# I : 242 Train-Acc : 0.819 Test-Acc : 0.8702
# I : 243 Train-Acc : 0.823 Test-Acc : 0.8707
# I : 244 Train-Acc : 0.817 Test-Acc : 0.871
# I : 245 Train-Acc : 0.815 Test-Acc : 0.8701
# I : 246 Train-Acc : 0.819 Test-Acc : 0.8705
# I : 247 Train-Acc : 0.807 Test-Acc : 0.8709
# I : 248 Train-Acc : 0.815 Test-Acc : 0.871
# I : 249 Train-Acc : 0.819 Test-Acc : 0.8721
# I : 250 Train-Acc : 0.815 Test-Acc : 0.8708
# I : 251 Train-Acc : 0.814 Test-Acc : 0.8706
# I : 252 Train-Acc : 0.813 Test-Acc : 0.8714
# I : 253 Train-Acc : 0.814 Test-Acc : 0.8719
# I : 254 Train-Acc : 0.827 Test-Acc : 0.8707
# I : 255 Train-Acc : 0.815 Test-Acc : 0.8719
# I : 256 Train-Acc : 0.81 Test-Acc : 0.8723
# I : 257 Train-Acc : 0.831 Test-Acc : 0.872
# I : 258 Train-Acc : 0.826 Test-Acc : 0.8719
# I : 259 Train-Acc : 0.81 Test-Acc : 0.871
# I : 260 Train-Acc : 0.809 Test-Acc : 0.8713
# I : 261 Train-Acc : 0.805 Test-Acc : 0.8718
# I : 262 Train-Acc : 0.826 Test-Acc : 0.8714
# I : 263 Train-Acc : 0.824 Test-Acc : 0.872
# I : 264 Train-Acc : 0.818 Test-Acc : 0.8716
# I : 265 Train-Acc : 0.821 Test-Acc : 0.8712
# I : 266 Train-Acc : 0.824 Test-Acc : 0.8715
# I : 267 Train-Acc : 0.827 Test-Acc : 0.8709
# I : 268 Train-Acc : 0.827 Test-Acc : 0.8714
# I : 269 Train-Acc : 0.823 Test-Acc : 0.8719
# I : 270 Train-Acc : 0.82 Test-Acc : 0.8716
# I : 271 Train-Acc : 0.821 Test-Acc : 0.8719
# I : 272 Train-Acc : 0.824 Test-Acc : 0.8705
# I : 273 Train-Acc : 0.824 Test-Acc : 0.8708
# I : 274 Train-Acc : 0.812 Test-Acc : 0.8711
# I : 275 Train-Acc : 0.83 Test-Acc : 0.8714
# I : 276 Train-Acc : 0.827 Test-Acc : 0.8712
# I : 277 Train-Acc : 0.818 Test-Acc : 0.8713
# I : 278 Train-Acc : 0.822 Test-Acc : 0.8713
# I : 279 Train-Acc : 0.825 Test-Acc : 0.8719
# I : 280 Train-Acc : 0.832 Test-Acc : 0.8722
# I : 281 Train-Acc : 0.824 Test-Acc : 0.8717
# I : 282 Train-Acc : 0.821 Test-Acc : 0.872
# I : 283 Train-Acc : 0.832 Test-Acc : 0.8714
# I : 284 Train-Acc : 0.819 Test-Acc : 0.8712
# I : 285 Train-Acc : 0.829 Test-Acc : 0.8715
# I : 286 Train-Acc : 0.83 Test-Acc : 0.8699
# I : 287 Train-Acc : 0.831 Test-Acc : 0.8703
# I : 288 Train-Acc : 0.831 Test-Acc : 0.8709
# I : 289 Train-Acc : 0.829 Test-Acc : 0.8704
# I : 290 Train-Acc : 0.815 Test-Acc : 0.871
# I : 291 Train-Acc : 0.823 Test-Acc : 0.8708
# I : 292 Train-Acc : 0.823 Test-Acc : 0.8709
# I : 293 Train-Acc : 0.832 Test-Acc : 0.8712
# I : 294 Train-Acc : 0.823 Test-Acc : 0.8709
# I : 295 Train-Acc : 0.82 Test-Acc : 0.8708
# I : 296 Train-Acc : 0.818 Test-Acc : 0.8711
# I : 297 Train-Acc : 0.842 Test-Acc : 0.8715
# I : 298 Train-Acc : 0.827 Test-Acc : 0.8716
# I : 299 Train-Acc : 0.832 Test-Acc : 0.8708
