# %% [markdown]
# ## Библиотеки

# %%
import numpy as np
import sys
from keras.datasets import mnist

# %% [markdown]
# ## Данные

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# Возьмем 1000 наблюдений и вытянем картинки в вектор и отцентрируем и нормируем. 
images, labels = x_train[0:1000].reshape(1000, 28*28) / 255, y_train[0:1000]
# Закодируем категориальный признак.
one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels
test_images = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
    test_labels[i][l] = 1

# %%
def tanh(x):
    return np.tanh(x)

def tang2deriv(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims=True)

# %%
# Зададим параметры.
alpha = 2
iterations = 300
hidden_size = 100
pixels_per_image = 784
num_labels = 10
batch_size = 100

# %%
# Создадим веса.
np.random.seed(1)
weights_0_1 = 0.02 * np.random.random((pixels_per_image, hidden_size)) - 0.01
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

# %%
for iter in range(iterations):
    correct_cnt = 0
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end = (i* batch_size, (i+1) * batch_size)
        
        layer_0 = images[batch_start : batch_end]
        layer_1 = tanh(layer_0.dot(weights_0_1))
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = softmax(layer_1.dot(weights_1_2))
        
        for k in range(batch_size):
            correct_cnt += int(np.argmax(layer_2[k : k+1]) == np.argmax(labels[batch_start+k : batch_start+k+1]))
            
        layer_2_delta = (layer_2 - labels[batch_start : batch_end]) / batch_size * layer_2.shape[0]
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * tang2deriv(layer_1)
        layer_1_delta *= dropout_mask
        
        weights_delta_1_2 = layer_1.T.dot(layer_2_delta)
        weights_delta_0_1 = layer_0.T.dot(layer_1_delta)
        
        weights_1_2 -= alpha * weights_delta_1_2
        weights_0_1 -= alpha * weights_delta_0_1
            
    test_correct_cnt = 0
    for j in range(len(test_labels)):
        layer_0 = test_images[j : j+1]
        layer_1 = tanh(layer_0.dot(weights_0_1))
        layer_2 = softmax(layer_1.dot(weights_1_2))
        
        test_correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[j : j+1]))
        
    sys.stdout.write('\n' + 'I : ' + str(iter) + ' Train-Acc : ' + str(correct_cnt/float(len(images))) + ' Test-Acc : ' + str(test_correct_cnt/float(len(test_images))))
    print()
# Out:
# C:\Users\arkad\AppData\Local\Temp\ipykernel_10540\337410072.py:8: RuntimeWarning: overflow encountered in exp
#   temp = np.exp(x)
# C:\Users\arkad\AppData\Local\Temp\ipykernel_10540\337410072.py:9: RuntimeWarning: invalid value encountered in divide
#   return temp / np.sum(temp, axis=1, keepdims=True)
# I : 0 Train-Acc : 0.089 Test-Acc : 0.098
#
# I : 1 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 2 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 3 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 4 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 5 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 6 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 7 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 8 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 9 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 10 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 11 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 12 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 13 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 14 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 15 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 16 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 17 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 18 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 19 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 20 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 21 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 22 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 23 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 24 Train-Acc : 0.097 Test-Acc : 0.098
#
# I : 25 Train-Acc : 0.097 Test-Acc : 0.098
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 31
#      28     layer_1 = tanh(layer_0.dot(weights_0_1))
#      29     layer_2 = softmax(layer_1.dot(weights_1_2))
# ---> 31     test_correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[j : j+1]))
#      33 sys.stdout.write('\n' + 'I : ' + str(iter) + ' Train-Acc : ' + str(correct_cnt/float(len(images))) + ' Test-Acc : ' + str(test_correct_cnt/float(len(test_images))))
#      34 print()
#
# File c:\Users\arkad\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:1229, in argmax(a, axis, out, keepdims)
#    1142 """
#    1143 Returns the indices of the maximum values along an axis.
#    1144
#    (...)
#    1226 (2, 1, 4)
#    1227 """
#    1228 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File c:\Users\arkad\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:
